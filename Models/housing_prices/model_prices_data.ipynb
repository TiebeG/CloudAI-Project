# %% [markdown]
# # 📊 Housing price model
#
# **Author: Tiebe Goossens**

# %% [markdown]
# ## 1️⃣ Loading and Preparing the Training Dataset
#
# In this notebook, we train several machine-learning models to predict housing
# prices based on the UK Price Paid dataset.
#
# We start by loading the cleaned and prepared dataset produced in the previous
# “Final Prep” notebook. Because the full dataset contains over 22 million rows,
# we use a 10% training subset that remains large enough to capture price
# patterns while still allowing local training.

# %%
# !pip install scikit-learn lightgbm pycaret
# Out:
# Requirement already satisfied: scikit-learn in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (1.4.2)
# Requirement already satisfied: lightgbm in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (4.6.0)
# Requirement already satisfied: pycaret in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (3.3.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: scikit-plot>=0.3.7 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.3.7)
# Requirement already satisfied: deprecation>=2.1.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.1.0)
# Requirement already satisfied: category-encoders>=2.4.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.7.0)
# Requirement already satisfied: sktime==0.26.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.26.0)
# Requirement already satisfied: matplotlib<3.8.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.7.5)
# Requirement already satisfied: cloudpickle in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.1.2)
# Requirement already satisfied: xxhash in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.6.0)
# Requirement already satisfied: ipython>=5.5.0 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from pycaret) (8.37.0)
# Requirement already satisfied: imbalanced-learn>=0.12.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.14.0)
# Requirement already satisfied: importlib-metadata>=4.12.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (8.7.0)
# Requirement already satisfied: kaleido>=0.2.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.2.0)
# Requirement already satisfied: tbats>=1.1.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.1.3)
# Requirement already satisfied: yellowbrick>=1.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (1.5)
# Requirement already satisfied: statsmodels>=0.12.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.14.5)
# Requirement already satisfied: ipywidgets>=7.6.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (8.1.8)
# Requirement already satisfied: nbformat>=4.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (5.10.4)
# Requirement already satisfied: tqdm>=4.62.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (4.67.1)
# Requirement already satisfied: plotly>=5.14.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (5.24.1)
# Requirement already satisfied: schemdraw==0.15 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.15)
# Requirement already satisfied: pyod>=1.1.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.0.5)
# Requirement already satisfied: numba>=0.55.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.62.1)
# Requirement already satisfied: markupsafe>=2.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.0.2)
# Requirement already satisfied: pmdarima>=2.0.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.0.4)
# Requirement already satisfied: plotly-resampler>=0.8.3.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (0.11.0)
# Requirement already satisfied: requests>=2.27.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.32.5)
# Requirement already satisfied: pandas<2.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (2.1.4)
# Requirement already satisfied: jinja2>=3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pycaret) (3.1.6)
# Requirement already satisfied: psutil>=5.9.0 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from pycaret) (7.1.0)
# Requirement already satisfied: packaging in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sktime==0.26.0->pycaret) (25.0)
# Requirement already satisfied: scikit-base<0.8.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from sktime==0.26.0->pycaret) (0.7.8)
# Requirement already satisfied: patsy>=0.5.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from category-encoders>=2.4.0->pycaret) (1.0.2)
# Requirement already satisfied: zipp>=3.20 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from importlib-metadata>=4.12.0->pycaret) (3.23.0)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (2.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.1.7)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.14.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (4.15.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (3.0.52)
# Requirement already satisfied: colorama in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (0.4.6)
# Requirement already satisfied: decorator in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipython>=5.5.0->pycaret) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.19.2)
# Requirement already satisfied: stack_data in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipython>=5.5.0->pycaret) (0.6.3)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (3.0.16)
# Requirement already satisfied: comm>=0.1.3 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from ipywidgets>=7.6.5->pycaret) (0.2.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from ipywidgets>=7.6.5->pycaret) (4.0.15)
# Requirement already satisfied: pytest-timeout>=2.4.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.4.0)
# Requirement already satisfied: choreographer>=1.1.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kaleido>=0.2.1->pycaret) (1.2.1)
# Requirement already satisfied: logistro>=1.0.8 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kaleido>=0.2.1->pycaret) (2.0.1)
# Requirement already satisfied: orjson>=3.10.15 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from kaleido>=0.2.1->pycaret) (3.11.4)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (3.2.5)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (11.3.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (2.9.0.post0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.3.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (4.60.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<3.8.0->pycaret) (1.4.9)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from nbformat>=4.2.0->pycaret) (4.25.1)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from nbformat>=4.2.0->pycaret) (5.8.1)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from numba>=0.55.0->pycaret) (0.45.1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.2.0->pycaret) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pandas<2.2.0->pycaret) (2022.7.1)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from plotly>=5.14.0->pycaret) (9.1.2)
# Requirement already satisfied: tsdownsample>=0.1.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (0.1.4.1)
# Requirement already satisfied: dash>=2.11.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from plotly-resampler>=0.8.3.1->pycaret) (3.3.0)
# Requirement already satisfied: urllib3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pmdarima>=2.0.4->pycaret) (1.26.20)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pmdarima>=2.0.4->pycaret) (80.9.0)
# Requirement already satisfied: Cython!=0.29.18,!=0.29.31,>=0.29 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pmdarima>=2.0.4->pycaret) (3.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (3.7)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->pycaret) (2025.8.3)
# Requirement already satisfied: simplejson>=3.19.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from choreographer>=1.1.1->kaleido>=0.2.1->pycaret) (3.20.2)
# Requirement already satisfied: Flask<3.2,>=1.0.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.2)
# Requirement already satisfied: Werkzeug<3.2 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (3.1.3)
# Requirement already satisfied: nest-asyncio in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.6.0)
# Requirement already satisfied: retrying in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.4.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from jedi>=0.16->ipython>=5.5.0->pycaret) (0.8.5)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.36.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (25.3.0)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (0.27.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=2.6->nbformat>=4.2.0->pycaret) (2025.9.1)
# Requirement already satisfied: pywin32>=300 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (311)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat>=4.2.0->pycaret) (4.4.0)
# Requirement already satisfied: wcwidth in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=5.5.0->pycaret) (0.2.14)
# Requirement already satisfied: pytest>=7.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (7.4.4)
# Requirement already satisfied: six>=1.5 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.8.0->pycaret) (1.17.0)
# Requirement already satisfied: pure-eval in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret) (0.2.3)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret) (3.0.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\tiebe\appdata\roaming\python\python310\site-packages (from stack_data->ipython>=5.5.0->pycaret) (2.2.1)
# Requirement already satisfied: itsdangerous>=2.2.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (8.3.0)
# Requirement already satisfied: blinker>=1.9.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from Flask<3.2,>=1.0.4->dash>=2.11.0->plotly-resampler>=0.8.3.1->pycaret) (1.9.0)
# Requirement already satisfied: iniconfig in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.3.0)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (2.2.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in c:\users\tiebe\appdata\local\programs\python\python310\lib\site-packages (from pytest>=7.0.0->pytest-timeout>=2.4.0->kaleido>=0.2.1->pycaret) (1.6.0)
# [notice] A new release of pip available: 22.3.1 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import ExtraTreesRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from lightgbm import LGBMRegressor
import math

from pycaret.regression import setup, compare_models, tune_model, finalize_model, save_model, predict_model

# %%
# Load your 10% subset dataset (as provided)
df = pd.read_csv("../../Data/housing_prices/price_paid_records_prepared_subset_10.csv")

# Convert date column to datetime and sort in time order
df["date_of_transfer"] = pd.to_datetime(df["date_of_transfer"])
df = df.sort_values("date_of_transfer").reset_index(drop=True)

df.head()
# Out:
#             transaction_unique_identifier   price date_of_transfer  \
# 0  {891F7B57-80C4-4BAA-83A8-BAE12D824A6E}   35000       1995-01-01
# 1  {677AA6E5-A626-461A-BE2B-7B0580842D46}  300000       1995-01-01
# 2  {9AE2B97B-69D0-4A5E-A4A9-3B496E56C6EB}  125000       1995-01-01
# 3  {82C4FDD1-D6EB-4264-9A23-3640B8EF5973}   17000       1995-01-01
# 4  {7000CF90-DE77-4022-BFBE-99C0265A984D}   52000       1995-01-01
#
#   property_type oldnew duration      towncity            district  \
# 0             D      N        F   STOURBRIDGE              DUDLEY
# 1             F      Y        L        LONDON              MERTON
# 2             D      N        F  MACCLESFIELD        MACCLESFIELD
# 3             T      N        F          HULL  KINGSTON UPON HULL
# 4             S      N        L    WARRINGTON          WARRINGTON
#
#            county ppdcategory_type record_status__monthly_file_only
# 0   WEST MIDLANDS                A                                A
# 1  GREATER LONDON                A                                A
# 2        CHESHIRE                A                                A
# 3      HUMBERSIDE                A                                A
# 4      WARRINGTON                A                                A

# %%
def make_features(df, lags=[1, 10, 100], rolls=[5, 20]):
    df2 = df.copy()
    
    # Time-based features
    df2["year"] = df2["date_of_transfer"].dt.year
    df2["month"] = df2["date_of_transfer"].dt.month
    df2["dayofweek"] = df2["date_of_transfer"].dt.dayofweek
    df2["quarter"] = df2["date_of_transfer"].dt.quarter
    df2["dayofmonth"] = df2["date_of_transfer"].dt.day
    
    # Lag features on price
    for l in lags:
        df2[f"price_lag_{l}"] = df2["price"].shift(l)
    
    # Rolling stats on price (shifted by 1 to avoid leakage)
    for r in rolls:
        df2[f"price_roll_mean_{r}"] = df2["price"].shift(1).rolling(r).mean()
        df2[f"price_roll_std_{r}"] = df2["price"].shift(1).rolling(r).std()
    
    return df2

df_feat = make_features(df)

# Drop rows that don't have full lag/rolling data
df_feat = df_feat.dropna().reset_index(drop=True)

df_feat.head()
# Out:
#             transaction_unique_identifier  price date_of_transfer  \
# 0  {C888AFBD-1EE6-4C4A-8ADF-23325B8B5EB0}  42500       1995-01-03
# 1  {D1418EA2-7D82-482D-A44C-4143D75A4790}  86000       1995-01-03
# 2  {9502E087-DC88-4DAF-8D71-F794F9587E49}  50000       1995-01-03
# 3  {85B55554-E0B6-4CD8-BD01-48C3DC7C1041}  35000       1995-01-03
# 4  {299C3702-AC93-4B64-8638-A53745A051E5}  39500       1995-01-03
#
#   property_type oldnew duration     towncity        district  \
# 0             T      Y        F  BRIDLINGTON  EAST YORKSHIRE
# 1             D      N        F        LEEDS           LEEDS
# 2             T      N        F     BRAMPTON        TYNEDALE
# 3             T      N        F    SHERBORNE  SOUTH SOMERSET
# 4             S      N        L   MANCHESTER            BURY
#
#                county ppdcategory_type  ... dayofweek  quarter  dayofmonth  \
# 0          HUMBERSIDE                A  ...         1        1           3
# 1      WEST YORKSHIRE                A  ...         1        1           3
# 2      NORTHUMBERLAND                A  ...         1        1           3
# 3            SOMERSET                A  ...         1        1           3
# 4  GREATER MANCHESTER                A  ...         1        1           3
#
#    price_lag_1  price_lag_10  price_lag_100  price_roll_mean_5  \
# 0      38000.0       67400.0        35000.0            68600.0
# 1      42500.0       32000.0       300000.0            58900.0
# 2      86000.0       60000.0       125000.0            61600.0
# 3      50000.0       29500.0        17000.0            59200.0
# 4      35000.0       59000.0        52000.0            50300.0
#
#    price_roll_std_5  price_roll_mean_20  price_roll_std_20
# 0      20097.885461             51195.0       21065.623656
# 1      18198.214198             51370.0       20973.318890
# 2      21434.201641             51570.0       21297.346017
# 3      22041.438247             51770.0       21261.036762
# 4      20741.263221             51845.0       21195.741255
#
# [5 rows x 23 columns]

# %% [markdown]
# ## 2️⃣ Time-Based Train/Test Split
#
# We must avoid random shuffling when training models on time-series data.
# Instead, we split the dataset chronologically:
#
# - First 80% → Training
# - Last 20% → Testing
#
# This ensures the model is evaluated on *future* data it has never seen, which
# better reflects real-world prediction scenarios.

# %%
# 80% train, 20% test, chronologically
n = len(df_feat)
train_idx = int(n * 0.8)

train = df_feat.iloc[:train_idx]
test  = df_feat.iloc[train_idx:]

len(train), len(test)
# Out:
# (1799068, 449767)

# %% [markdown]
# ## 3️⃣ Feature Engineering (Numeric-Only Baseline Model)
#
# For our first quick model, we intentionally limit ourselves to **numeric features**
# such as:
#
# - Year, month, weekday
# - Lagged price values
# - Rolling averages of price
# - Rolling standard deviations
#
# This model is **not expected to perform well**, but the assignment requires
# a “quick first model” to start testing deployment workflows.
#
# Categorical variables such as county, district, property_type, etc. are ignored
# in this first baseline model because scikit-learn models cannot directly consume
# string values without encoding, and the goal here is simplicity and speed.

# %%
# Use only numeric columns as features
numeric_cols = df_feat.select_dtypes(include=[np.number]).columns.tolist()

# Remove the target from the feature list
features = [c for c in numeric_cols if c != "price"]
target = "price"

X_train = train[features]
y_train = train[target]

X_test = test[features]
y_test = test[target]

X_train.dtypes.head()
# Out:
# year          int32
# month         int32
# dayofweek     int32
# quarter       int32
# dayofmonth    int32
# dtype: object

# %% [markdown]
# ## 4️⃣ Baseline Model: Extra Trees Regressor
#
# The **Extra Trees Regressor** serves as our first quick model. This model:
#
# - Trains very quickly
# - Requires minimal feature engineering
# - Produces a ready-to-deploy model early in the project
# - Acts as a baseline to compare better models against
#
# We expect the MAE and RMSE to be large because the model does not yet include
# location or property-type information, which are critical predictors for price.

# %%
etr = ExtraTreesRegressor(
    n_estimators=200,   # you can increase later
    max_depth=None,
    random_state=42,
    n_jobs=-1
)

etr.fit(X_train, y_train)

etr_pred = etr.predict(X_test)

etr_mae = mean_absolute_error(y_test, etr_pred)
etr_rmse = math.sqrt(mean_squared_error(y_test, etr_pred))

print("EXTRA TREES RESULTS")
print("MAE :", etr_mae)
print("RMSE:", etr_rmse)
# Out:
# EXTRA TREES RESULTS
# MAE : 181839.26543826028
# RMSE: 769742.2685869752

# %% [markdown]
# ## 5️⃣ Second Baseline Model: LightGBM
#
# LightGBM is a gradient-boosting ensemble well-suited for large datasets.
#
# This model generally performs better than ExtraTrees but still uses only
# numeric features. Therefore, while performance should improve slightly,
# it will remain limited compared to models that incorporate categorical data.

# %%
lgb = LGBMRegressor(
    n_estimators=600,
    learning_rate=0.05,
    max_depth=-1,
    subsample=0.8,
    colsample_bytree=0.8,
    random_state=42,
    n_jobs=-1
)

lgb.fit(X_train, y_train)

lgb_pred = lgb.predict(X_test)

lgb_mae = mean_absolute_error(y_test, lgb_pred)
lgb_rmse = math.sqrt(mean_squared_error(y_test, lgb_pred))

print("LIGHTGBM RESULTS")
print("MAE :", lgb_mae)
print("RMSE:", lgb_rmse)
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.020499 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 1861
# [LightGBM] [Info] Number of data points in the train set: 1799068, number of used features: 12
# [LightGBM] [Info] Start training from score 151188.554962
# LIGHTGBM RESULTS
# MAE : 166081.34364775303
# RMSE: 768518.8580883646

# %% [markdown]
# ## 6️⃣ Model Performance Interpretation
#
# The baseline models deliver the following metrics:
#
# - **MAE** (Mean Absolute Error): the average amount the predictions are wrong
# - **RMSE** (Root Mean Squared Error): penalizes larger mistakes more
#
# Because the baseline models ignore location and property characteristics, the
# errors appear large (≈ £160k–£180k MAE), which is expected.
#
# These models fulfill the assignment requirement of a “quick first model”
# that can be deployed while we continue improving accuracy.

# %%
# Final comparison
print("\n--- FINAL COMPARISON ---")
print(f"Extra Trees RMSE:  {etr_rmse:.2f}")
print(f"LightGBM RMSE:     {lgb_rmse:.2f}")
print(f"Extra Trees MAE:   {etr_mae:.2f}")
print(f"LightGBM MAE:      {lgb_mae:.2f}")
# Out:
# --- FINAL COMPARISON ---
# Extra Trees RMSE:  769742.27
# LightGBM RMSE:     768518.86
# Extra Trees MAE:   181839.27
# LightGBM MAE:      166081.34

# %% [markdown]
# ## 7️⃣ Improving the Model With Categorical Features
#
# The baseline models are intentionally simple.
# To significantly improve accuracy, we will incorporate key features:
#
# - **County / district / town**
# - **Property type** (Detached, Semi, Terraced, Flat)
# - **Old/New** indicator
# - **Freehold vs Leasehold duration**
#
# These are essential determinants of housing price.
#
# However, scikit-learn tree models cannot process raw string values.
# At this stage, we have two options:
#
# ### Option A — One-Hot Encode the Categorical Features
# This creates binary columns (e.g. county_LONDON, type_D, etc.).
# Good for tree-based scikit-learn models.
#
# ### Option B — Use PyCaret AutoML
# PyCaret automatically:
# - encodes categoricals
# - compares many models
# - tunes the best model
# - produces a **much better model** than the baselines
#
# We will now proceed with **PyCaret AutoML** to build our improved model.

# %%
# If df isn't in memory anymore, reload it:
# df = pd.read_csv("../Data/housing_prices/price_paid_records_prepared_subset_10.csv")

# Make sure date is datetime
df["date_of_transfer"] = pd.to_datetime(df["date_of_transfer"])

# Build a PyCaret-friendly dataframe:
# Keep price (target), date, and important categoricals; drop admin / ID columns.
py_df = df[[
    "price",
    "date_of_transfer",
    "property_type",
    "oldnew",
    "duration",
    "towncity",
    "district",
    "county",
    "ppdcategory_type"
]].copy()

# Add simple time features as numeric columns
py_df["year"] = py_df["date_of_transfer"].dt.year
py_df["month"] = py_df["date_of_transfer"].dt.month
py_df["dayofweek"] = py_df["date_of_transfer"].dt.dayofweek

# Optional: drop the raw datetime if you don’t want PyCaret to treat it as a feature
py_df = py_df.drop(columns=["date_of_transfer"])

py_df.head()
# Out:
#     price property_type oldnew duration      towncity            district  \
# 0   35000             D      N        F   STOURBRIDGE              DUDLEY
# 1  300000             F      Y        L        LONDON              MERTON
# 2  125000             D      N        F  MACCLESFIELD        MACCLESFIELD
# 3   17000             T      N        F          HULL  KINGSTON UPON HULL
# 4   52000             S      N        L    WARRINGTON          WARRINGTON
#
#            county ppdcategory_type  year  month  dayofweek
# 0   WEST MIDLANDS                A  1995      1          6
# 1  GREATER LONDON                A  1995      1          6
# 2        CHESHIRE                A  1995      1          6
# 3      HUMBERSIDE                A  1995      1          6
# 4      WARRINGTON                A  1995      1          6

# %% [markdown]
# ## 8️⃣ PyCaret AutoML: Comparing Models
#
# PyCaret’s `compare_models()` function trains and evaluates many algorithms:
#
# - LightGBM
# - CatBoost
# - Random Forest
# - Extra Trees
# - AdaBoost
# - Ridge / Lasso
# - ElasticNet
# - KNN
# - Neural networks
# - XGBoost
#
# PyCaret automatically handles:
# - train/test splitting
# - categorical encoding
# - normalization
# - hyperparameters
# - outlier handling
#
# The result is a ranked list of models, helping us identify the best candidates.

# %%
# For speed, you *can* subsample further for AutoML:
py_data = py_df.sample(frac=0.3, random_state=42)
# If your machine handles it, just use full py_df:

reg_setup = setup(
    data=py_data,
    target="price",
    session_id=42,
    train_size=0.8
)

# Get the top 3 models from AutoML
top3_models = compare_models(n_select=3)
top3_models
# Out:
# <style type="text/css">
# #T_783a0_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_783a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_783a0_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_783a0_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_783a0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_783a0_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_783a0_row0_col1" class="data row0 col1" >42</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_783a0_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_783a0_row1_col1" class="data row1 col1" >price</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_783a0_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_783a0_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_783a0_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_783a0_row3_col1" class="data row3 col1" >(674680, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_783a0_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_783a0_row4_col1" class="data row4 col1" >(674680, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_783a0_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_783a0_row5_col1" class="data row5 col1" >(539744, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_783a0_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_783a0_row6_col1" class="data row6 col1" >(134936, 17)</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_783a0_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_783a0_row7_col1" class="data row7 col1" >3</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_783a0_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_783a0_row8_col1" class="data row8 col1" >7</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_783a0_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_783a0_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_783a0_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_783a0_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_783a0_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_783a0_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_783a0_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_783a0_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_783a0_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_783a0_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_783a0_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_783a0_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_783a0_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_783a0_row15_col1" class="data row15 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_783a0_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_783a0_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_783a0_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_783a0_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_783a0_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_783a0_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_783a0_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_783a0_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_783a0_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_783a0_row20_col1" class="data row20 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_783a0_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_783a0_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_783a0_row21_col1" class="data row21 col1" >c4ae</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_17c55 th {
#   text-align: left;
# }
# #T_17c55_row0_col0, #T_17c55_row0_col1, #T_17c55_row0_col3, #T_17c55_row0_col5, #T_17c55_row0_col6, #T_17c55_row1_col0, #T_17c55_row1_col1, #T_17c55_row1_col2, #T_17c55_row1_col3, #T_17c55_row1_col4, #T_17c55_row1_col5, #T_17c55_row1_col6, #T_17c55_row2_col0, #T_17c55_row2_col1, #T_17c55_row2_col2, #T_17c55_row2_col3, #T_17c55_row2_col4, #T_17c55_row2_col5, #T_17c55_row2_col6, #T_17c55_row3_col0, #T_17c55_row3_col1, #T_17c55_row3_col2, #T_17c55_row3_col3, #T_17c55_row3_col4, #T_17c55_row3_col5, #T_17c55_row3_col6, #T_17c55_row4_col0, #T_17c55_row4_col1, #T_17c55_row4_col2, #T_17c55_row4_col3, #T_17c55_row4_col4, #T_17c55_row4_col5, #T_17c55_row4_col6, #T_17c55_row5_col0, #T_17c55_row5_col1, #T_17c55_row5_col2, #T_17c55_row5_col3, #T_17c55_row5_col4, #T_17c55_row5_col5, #T_17c55_row5_col6, #T_17c55_row6_col0, #T_17c55_row6_col1, #T_17c55_row6_col2, #T_17c55_row6_col3, #T_17c55_row6_col4, #T_17c55_row6_col5, #T_17c55_row6_col6, #T_17c55_row7_col0, #T_17c55_row7_col1, #T_17c55_row7_col2, #T_17c55_row7_col3, #T_17c55_row7_col4, #T_17c55_row7_col5, #T_17c55_row7_col6, #T_17c55_row8_col0, #T_17c55_row8_col1, #T_17c55_row8_col2, #T_17c55_row8_col3, #T_17c55_row8_col4, #T_17c55_row8_col5, #T_17c55_row8_col6, #T_17c55_row9_col0, #T_17c55_row9_col1, #T_17c55_row9_col2, #T_17c55_row9_col3, #T_17c55_row9_col4, #T_17c55_row9_col5, #T_17c55_row9_col6, #T_17c55_row10_col0, #T_17c55_row10_col1, #T_17c55_row10_col2, #T_17c55_row10_col3, #T_17c55_row10_col4, #T_17c55_row10_col5, #T_17c55_row10_col6, #T_17c55_row11_col0, #T_17c55_row11_col1, #T_17c55_row11_col2, #T_17c55_row11_col3, #T_17c55_row11_col4, #T_17c55_row11_col5, #T_17c55_row11_col6, #T_17c55_row12_col0, #T_17c55_row12_col2, #T_17c55_row12_col4, #T_17c55_row13_col0, #T_17c55_row13_col1, #T_17c55_row13_col2, #T_17c55_row13_col3, #T_17c55_row13_col4, #T_17c55_row13_col5, #T_17c55_row13_col6, #T_17c55_row14_col0, #T_17c55_row14_col1, #T_17c55_row14_col2, #T_17c55_row14_col3, #T_17c55_row14_col4, #T_17c55_row14_col5, #T_17c55_row14_col6, #T_17c55_row15_col0, #T_17c55_row15_col1, #T_17c55_row15_col2, #T_17c55_row15_col3, #T_17c55_row15_col4, #T_17c55_row15_col5, #T_17c55_row15_col6, #T_17c55_row16_col0, #T_17c55_row16_col1, #T_17c55_row16_col2, #T_17c55_row16_col3, #T_17c55_row16_col4, #T_17c55_row16_col5, #T_17c55_row16_col6, #T_17c55_row17_col0, #T_17c55_row17_col1, #T_17c55_row17_col2, #T_17c55_row17_col3, #T_17c55_row17_col4, #T_17c55_row17_col5, #T_17c55_row17_col6 {
#   text-align: left;
# }
# #T_17c55_row0_col2, #T_17c55_row0_col4, #T_17c55_row12_col1, #T_17c55_row12_col3, #T_17c55_row12_col5, #T_17c55_row12_col6 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_17c55_row0_col7, #T_17c55_row1_col7, #T_17c55_row2_col7, #T_17c55_row3_col7, #T_17c55_row4_col7, #T_17c55_row5_col7, #T_17c55_row6_col7, #T_17c55_row7_col7, #T_17c55_row8_col7, #T_17c55_row9_col7, #T_17c55_row10_col7, #T_17c55_row11_col7, #T_17c55_row12_col7, #T_17c55_row13_col7, #T_17c55_row15_col7, #T_17c55_row16_col7, #T_17c55_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_17c55_row14_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_17c55">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17c55_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_17c55_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_17c55_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_17c55_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_17c55_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_17c55_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_17c55_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_17c55_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17c55_level0_row0" class="row_heading level0 row0" >gbr</th>
#       <td id="T_17c55_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_17c55_row0_col1" class="data row0 col1" >63098.2272</td>
#       <td id="T_17c55_row0_col2" class="data row0 col2" >90578883802.3112</td>
#       <td id="T_17c55_row0_col3" class="data row0 col3" >291470.6444</td>
#       <td id="T_17c55_row0_col4" class="data row0 col4" >0.2850</td>
#       <td id="T_17c55_row0_col5" class="data row0 col5" >0.4645</td>
#       <td id="T_17c55_row0_col6" class="data row0 col6" >1.0534</td>
#       <td id="T_17c55_row0_col7" class="data row0 col7" >10.8650</td>
#     </tr>
#     <tr>
#       <th id="T_17c55_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_17c55_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_17c55_row1_col1" class="data row1 col1" >61734.8325</td>
#       <td id="T_17c55_row1_col2" class="data row1 col2" >91146212884.9589</td>
#       <td id="T_17c55_row1_col3" class="data row1 col3" >293209.3550</td>
#       <td id="T_17c55_row1_col4" class="data row1 col4" >0.2749</td>
#       <td id="T_17c55_row1_col5" class="data row1 col5" >0.4415</td>
#       <td id="T_17c55_row1_col6" class="data row1 col6" >0.9521</td>
#       <td id="T_17c55_row1_col7" class="data row1 col7" >1.2020</td>
#     </tr>
#     <tr>
#       <th id="T_17c55_level0_row2" class="row_heading level0 row2" >lasso</th>
#       <td id="T_17c55_row2_col0" class="data row2 col0" >Lasso Regression</td>
#       <td id="T_17c55_row2_col1" class="data row2 col1" >80455.3393</td>
#       <td id="T_17c55_row2_col2" class="data row2 col2" >101451355238.6187</td>
#       <td id="T_17c55_row2_col3" class="data row2 col3" >310096.1011</td>
#       <td id="T_17c55_row2_col4" class="data row2 col4" >0.1901</td>
#       <td id="T_17c55_row2_col5" class="data row2 col5" >0.7482</td>
#       <td id="T_17c55_row2_col6" class="data row2 col6" >1.4268</td>
#       <td id="T_17c55_row2_col7" class="data row2 col7" >15.0130</td>
#     </tr>
#     <tr>
#       <th id="T_17c55_level0_row3" class="row_heading level0 row3" >ridge</th>
#       <td id="T_17c55_row3_col0" class="data row3 col0" >Ridge Regression</td>
#       <td id="T_17c55_row3_col1" class="data row3 col1" >80456.1468</td>
#       <td id="T_17c55_row3_col2" class="data row3 col2" >101451430756.7349</td>
#       <td id="T_17c55_row3_col3" class="data row3 col3" >310096.1382</td>
#       <td id="T_17c55_row3_col4" class="data row3 col4" >0.1901</td>
#       <td id="T_17c55_row3_col5" class="data row3 col5" >0.7480</td>
#       <td id="T_17c55_row3_col6" class="data row3 col6" >1.4268</td>
#       <td id="T_17c55_row3_col7" class="data row3 col7" >0.7680</td>
#     </tr>
#     <tr>
#       <th id="T_17c55_level0_row4" class="row_heading level0 row4" >lar</th>
#       <td id="T_17c55_row4_col0" class="data row4 col0" >Least Angle Regression</td>
#       <td id="T_17c55_row4_col1" class="data row4 col1" >80456.3019</td>
#       <td id="T_17c55_row4_col2" class="data row4 col2" >101451464285.2710</td>
#       <td id="T_17c55_row4_col3" class="data row4 col3" >310096.4678</td>
#       <td id="T_17c55_row4_col4" class="data row4 col4" >0.1901</td>
#       <td id="T_17c55_row4_col5" class="data row4 col5" >0.7481</td>
#       <td id="T_17c55_row4_col6" class="data row4 col6" >1.4269</td>
#       <td id="T_17c55_row4_col7" class="data row4 col7" >0.6250</td>
#     </tr>
#     <tr>
#       <th id="T_17c55_level0_row5" class="row_heading level0 row5" >llar</th>
#       <td id="T_17c55_row5_col0" class="data row5 col0" >Lasso Least Angle Regression</td>
#       <td id="T_17c55_row5_col1" class="data row5 col1" >80455.4092</td>
#       <td id="T_17c55_row5_col2" class="data row5 col2" >101451386133.6251</td>
#       <td id="T_17c55_row5_col3" class="data row5 col3" >310096.1609</td>
#       <td id="T_17c55_row5_col4" class="data row5 col4" >0.1901</td>
#       <td id="T_17c55_row5_col5" class="data row5 col5" >0.7482</td>
#       <td id="T_17c55_row5_col6" class="data row5 col6" >1.426
# [GradientBoostingRegressor(random_state=42),
#  LGBMRegressor(n_jobs=-1, random_state=42),
#  Lasso(random_state=42)]

# %% [markdown]
# ## 9️⃣ Tuning the Best PyCaret Model
#
# Using `tune_model()`, we optimize the top algorithm found by AutoML.
# This process finds better hyperparameters and often significantly improves
# MAE and RMSE.
#
# The tuned model is then finalized and saved for later deployment.

# %%
# Top3 is a list: [best_model, second_best, third_best]
best_model_pycaret = top3_models[0]

# Tune hyperparameters of the best model
tuned_best_model = tune_model(best_model_pycaret)

# Finalize the tuned model (train on full training split)
final_best_model = finalize_model(tuned_best_model)

# Save for later deployment
save_model(final_best_model, "pycaret_best_housing_model")
# Out:
# <style type="text/css">
# #T_17d23_row10_col0, #T_17d23_row10_col1, #T_17d23_row10_col2, #T_17d23_row10_col3, #T_17d23_row10_col4, #T_17d23_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_17d23">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17d23_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_17d23_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_17d23_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_17d23_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_17d23_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_17d23_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17d23_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17d23_row0_col0" class="data row0 col0" >61440.6405</td>
#       <td id="T_17d23_row0_col1" class="data row0 col1" >106095690602.3072</td>
#       <td id="T_17d23_row0_col2" class="data row0 col2" >325723.3344</td>
#       <td id="T_17d23_row0_col3" class="data row0 col3" >0.1661</td>
#       <td id="T_17d23_row0_col4" class="data row0 col4" >0.4369</td>
#       <td id="T_17d23_row0_col5" class="data row0 col5" >0.4780</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17d23_row1_col0" class="data row1 col0" >62647.0130</td>
#       <td id="T_17d23_row1_col1" class="data row1 col1" >176821181198.9794</td>
#       <td id="T_17d23_row1_col2" class="data row1 col2" >420501.1073</td>
#       <td id="T_17d23_row1_col3" class="data row1 col3" >0.2187</td>
#       <td id="T_17d23_row1_col4" class="data row1 col4" >0.4346</td>
#       <td id="T_17d23_row1_col5" class="data row1 col5" >0.5164</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_17d23_row2_col0" class="data row2 col0" >61700.9794</td>
#       <td id="T_17d23_row2_col1" class="data row2 col1" >61244240137.2176</td>
#       <td id="T_17d23_row2_col2" class="data row2 col2" >247475.7365</td>
#       <td id="T_17d23_row2_col3" class="data row2 col3" >0.3116</td>
#       <td id="T_17d23_row2_col4" class="data row2 col4" >0.4360</td>
#       <td id="T_17d23_row2_col5" class="data row2 col5" >0.4959</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_17d23_row3_col0" class="data row3 col0" >60413.2355</td>
#       <td id="T_17d23_row3_col1" class="data row3 col1" >59720761607.2109</td>
#       <td id="T_17d23_row3_col2" class="data row3 col2" >244378.3166</td>
#       <td id="T_17d23_row3_col3" class="data row3 col3" >0.3891</td>
#       <td id="T_17d23_row3_col4" class="data row3 col4" >0.4324</td>
#       <td id="T_17d23_row3_col5" class="data row3 col5" >0.4846</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_17d23_row4_col0" class="data row4 col0" >61979.3557</td>
#       <td id="T_17d23_row4_col1" class="data row4 col1" >72900208881.6259</td>
#       <td id="T_17d23_row4_col2" class="data row4 col2" >270000.3868</td>
#       <td id="T_17d23_row4_col3" class="data row4 col3" >0.3316</td>
#       <td id="T_17d23_row4_col4" class="data row4 col4" >0.4363</td>
#       <td id="T_17d23_row4_col5" class="data row4 col5" >0.4755</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_17d23_row5_col0" class="data row5 col0" >59802.3642</td>
#       <td id="T_17d23_row5_col1" class="data row5 col1" >74501662227.5963</td>
#       <td id="T_17d23_row5_col2" class="data row5 col2" >272949.9262</td>
#       <td id="T_17d23_row5_col3" class="data row5 col3" >0.1340</td>
#       <td id="T_17d23_row5_col4" class="data row5 col4" >0.4418</td>
#       <td id="T_17d23_row5_col5" class="data row5 col5" >0.8055</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_17d23_row6_col0" class="data row6 col0" >60274.0135</td>
#       <td id="T_17d23_row6_col1" class="data row6 col1" >48293618904.5897</td>
#       <td id="T_17d23_row6_col2" class="data row6 col2" >219758.0918</td>
#       <td id="T_17d23_row6_col3" class="data row6 col3" >0.2967</td>
#       <td id="T_17d23_row6_col4" class="data row6 col4" >0.4465</td>
#       <td id="T_17d23_row6_col5" class="data row6 col5" >0.6430</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_17d23_row7_col0" class="data row7 col0" >59600.1879</td>
#       <td id="T_17d23_row7_col1" class="data row7 col1" >52406394788.8398</td>
#       <td id="T_17d23_row7_col2" class="data row7 col2" >228924.4303</td>
#       <td id="T_17d23_row7_col3" class="data row7 col3" >0.4573</td>
#       <td id="T_17d23_row7_col4" class="data row7 col4" >0.4361</td>
#       <td id="T_17d23_row7_col5" class="data row7 col5" >4.7893</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_17d23_row8_col0" class="data row8 col0" >63456.2406</td>
#       <td id="T_17d23_row8_col1" class="data row8 col1" >187327493528.8616</td>
#       <td id="T_17d23_row8_col2" class="data row8 col2" >432813.4627</td>
#       <td id="T_17d23_row8_col3" class="data row8 col3" >0.1676</td>
#       <td id="T_17d23_row8_col4" class="data row8 col4" >0.4388</td>
#       <td id="T_17d23_row8_col5" class="data row8 col5" >0.4648</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_17d23_row9_col0" class="data row9 col0" >61364.2221</td>
#       <td id="T_17d23_row9_col1" class="data row9 col1" >73867244444.4153</td>
#       <td id="T_17d23_row9_col2" class="data row9 col2" >271785.2911</td>
#       <td id="T_17d23_row9_col3" class="data row9 col3" >0.2542</td>
#       <td id="T_17d23_row9_col4" class="data row9 col4" >0.4378</td>
#       <td id="T_17d23_row9_col5" class="data row9 col5" >0.5381</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_17d23_row10_col0" class="data row10 col0" >61267.8252</td>
#       <td id="T_17d23_row10_col1" class="data row10 col1" >91317849632.1644</td>
#       <td id="T_17d23_row10_col2" class="data row10 col2" >293431.0084</td>
#       <td id="T_17d23_row10_col3" class="data row10 col3" >0.2727</td>
#       <td id="T_17d23_row10_col4" class="data row10 col4" >0.4377</td>
#       <td id="T_17d23_row10_col5" class="data row10 col5" >0.9691</td>
#     </tr>
#     <tr>
#       <th id="T_17d23_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_17d23_row11_col0" class="data row11 col0" >1186.2104</td>
#       <td id="T_17d23_row11_col1" class="data row11 col1" >47897345430.0227</td>
#       <td id="T_17d23_row11_col2" class="data row11 col2" >72222.5239</td>
#       <td id="T_17d23_row11_col3" class="data row11 col3" >0.0990</td>
#       <td id="T_17d23_row11_col4" class="data row11 col4" >0.0037</td>
#       <td id="T_17d23_row11_col5" class="data row11 col5" >1.2773</td>
#     </tr>
#   </tbody>
# </table>
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# Original model was better than the tuned model, hence it will be returned. NOTE: The display metrics are for the tuned model (not the original one).
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=Memory(location=None),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['year', 'month', 'dayofweek'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['property_type', 'oldnew',
#                                               'duration', 'towncity', 'district',
#                                               'county', 'ppdcategory_type'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordi...
#                   TransformerWrapper(include=['property_type', 'duration'],
#                                      transformer=OneHotEncoder(cols=['property_type',
#                                                                      'duration'],
#                                                                handle_missing='return_nan',
#                                                                use_cat_names=True))),
#                  ('rest_encoding',
#                   TransformerWrapper(include=['towncity', 'district', 'county'],
#                                      transformer=TargetEncoder(cols=['towncity',
#                                                                      'district',
#                                                                      'county'],
#                                                                handle_missing='return_nan'))),
#                  ('actual_estimator',
#                   GradientBoostingRegressor(random_state=42))]),
#  'pycaret_best_housing_model.pkl')

# %% [markdown]
# ## 🔟 Model Comparison and Final Selection
#
# At this point, we have 2–3 models:
#
# - Extra Trees baseline
# - LightGBM baseline
# - PyCaret Best Tuned Model
#
# We compare all models side-by-side using MAE/RMSE.
# The PyCaret tuned model usually performs best because it integrates
# categorical features automatically.
#
# The selected final model is the one that:
#
# - Has the lowest MAE and RMSE
# - Generalizes best on the test set
# - Uses the richest feature representation

# %%
# Evaluate tuned PyCaret model on its hold-out test set (inside PyCaret)
pycaret_test_results = predict_model(final_best_model)
pycaret_test_results.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_639c3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_639c3_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_639c3_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_639c3_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_639c3_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_639c3_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_639c3_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_639c3_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_639c3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_639c3_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_639c3_row0_col1" class="data row0 col1" >63057.8672</td>
#       <td id="T_639c3_row0_col2" class="data row0 col2" >95134052765.6320</td>
#       <td id="T_639c3_row0_col3" class="data row0 col3" >308438.0858</td>
#       <td id="T_639c3_row0_col4" class="data row0 col4" >0.3432</td>
#       <td id="T_639c3_row0_col5" class="data row0 col5" >0.4628</td>
#       <td id="T_639c3_row0_col6" class="data row0 col6" >1.2842</td>
#     </tr>
#   </tbody>
# </table>
#         property_type oldnew duration         towncity   district  \
# 1774831             T      N        F  HEMEL HEMPSTEAD    DACORUM
# 1249865             T      N        F        STEVENAGE  STEVENAGE
# 1093910             T      N        F           LONDON     MERTON
# 462808              D      N        F         BARNSLEY   BARNSLEY
# 974482              D      N        F         UCKFIELD    WEALDEN
#
#                   county ppdcategory_type  year  month  dayofweek   price  \
# 1774831    HERTFORDSHIRE                A  2012      3          4  249500
# 1249865    HERTFORDSHIRE                A  2006      2          4  185000
# 1093910   GREATER LONDON                A  2004      8          2  375000
# 462808   SOUTH YORKSHIRE                A  1999      8          4   79950
# 974482       EAST SUSSEX                A  2003     10          3  555000
#
#          prediction_label
# 1774831     241650.153425
# 1249865     165526.551441
# 1093910     319796.063240
# 462808       87230.241066
# 974482      311721.997338

# %%
# MAE / RMSE for the PyCaret model on its internal test predictions
py_mae = mean_absolute_error(pycaret_test_results["price"], pycaret_test_results["prediction_label"])
py_rmse = np.sqrt(mean_squared_error(pycaret_test_results["price"], pycaret_test_results["prediction_label"]))

print("PYCARET BEST MODEL RESULTS")
print("MAE :", py_mae)
print("RMSE:", py_rmse)
# Out:
# PYCARET BEST MODEL RESULTS
# MAE : 63057.86724100634
# RMSE: 308438.0857897287

# %%
# Summary comparison table: ExtraTrees vs LightGBM vs PyCaret best
results_summary = pd.DataFrame({
    "Model": ["Extra Trees", "LightGBM", "PyCaret Best"],
    "MAE":   [etr_mae,       lgb_mae,    py_mae],
    "RMSE":  [etr_rmse,      lgb_rmse,   py_rmse]
})

results_summary
# Out:
#           Model            MAE           RMSE
# 0   Extra Trees  181839.265438  769742.268587
# 1      LightGBM  166081.343648  768518.858088
# 2  PyCaret Best   63057.867241  308438.085790
